# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Finding Duplicates Lab**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# ## Introduction

# %% [markdown]
# Data wrangling is a critical step in preparing datasets for analysis, and handling duplicates plays a key role in ensuring data accuracy. In this lab, you will focus on identifying and removing duplicate entries from your dataset.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab, you will perform the following:

# %% [markdown]
# 1. Identify duplicate rows in the dataset and analyze their characteristics.
# 2. Visualize the distribution of duplicates based on key attributes.
# 3. Remove duplicate values strategically based on specific criteria.
# 4. Outline the process of verifying and documenting duplicate removal.

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# Install the needed library

# %%
# !pip install pandas
# !pip install matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 121.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 129.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 92.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 163.7 MB/s eta 0:00:00
# ...

# %% [markdown]
# Import pandas module

# %%
import pandas as pd

# %% [markdown]
# Import matplotlib

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## **Load the dataset into a dataframe**

# %% [markdown]
# <h2>Read Data</h2>
# <p>
# We utilize the <code>pandas.read_csv()</code> function for reading CSV files. However, in this version of the lab, which operates on JupyterLite, the dataset needs to be downloaded to the interface using the provided code below.
# </p>

# %%
# Load the dataset directly from the URL
file_path = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/VYPrOu0Vs3I0hKLLjiPGrA/survey-data-with-duplicate.csv"
df = pd.read_csv(file_path)

# Display the first few rows
print(df.head())
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# ...

# %% [markdown]
# Load the data into a pandas dataframe:

# %% [markdown]
# Note: If you are working on a local Jupyter environment, you can use the URL directly in the pandas.read_csv() function as shown below:

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 65457 entries, 0 to 65456
# Columns: 114 entries, ResponseId to JobSat
# dtypes: float64(13), int64(1), str(100)
# memory usage: 56.9 MB

# %%
# df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv")

# %% [markdown]
# ## Identify and Analyze Duplicates

# %% [markdown]
# ### Task 1: Identify Duplicate Rows
# 1. Count the number of duplicate rows in the dataset.
# 3. Display the first few duplicate rows to understand their structure.

# %%
## Write your code here
df_duplicate_sum = df.duplicated().sum()
print("Total of duplicate values is:",df_duplicate_sum)
# Out:
# Total of duplicate values is: 20

# %%
df[df.duplicated()].head()
# Out:
#        ResponseId                      MainBranch                 Age  \
# 65437           1  I am a developer by profession  Under 18 years old
# 65438           2  I am a developer by profession     35-44 years old
# 65439           3  I am a developer by profession     45-54 years old
# 65440           4           I am learning to code     18-24 years old
# 65441           5  I am a developer by profession     18-24 years old
#
#                 Employment RemoteWork   Check  \
# 65437  Employed, full-time     Remote  Apples
# 65438  Employed, full-time     Remote  Apples
# 65439  Employed, full-time     Remote  Apples
# 65440   Student, full-time        NaN  Apples
# 65441   Student, full-time        NaN  Apples
#
#                                         CodingActivities  \
# 65437                                              Hobby
# 65438  Hobby;Contribute to open-source projects;Other...
# 65439  Hobby;Contribute to open-source projects;Other...
# ...

# %% [markdown]
# ### Task 2: Analysis of Duplicate Response Patterns
# 1. Identify duplicate response patterns based on selected columns such as MainBranch, Employment, and RemoteWork.
# 2. Clarify that these represent multiple respondents with identical answers rather than duplicate records. Analyse which other columns frequently share identical values within these response-pattern groups.

# %%
count_pattern = (df.groupby(["MainBranch","Employment","RemoteWork"]).size().reset_index(name="Count"))
count_pattern.sort_values("Count",ascending = False).head()
# Out:
#                         MainBranch  \
# 0   I am a developer by profession
# 2   I am a developer by profession
# 1   I am a developer by profession
# 78  I am a developer by profession
# 8   I am a developer by profession
#
#                                            Employment  \
# 0                                 Employed, full-time
# 2                                 Employed, full-time
# 1                                 Employed, full-time
# 78  Independent contractor, freelancer, or self-em...
# 8   Employed, full-time;Independent contractor, fr...
#
#                               RemoteWork  Count
# 0   Hybrid (some remote, some in-person)  15288
# 2                                 Remote  12196
# 1                              In-person   7118
# 78                                Remote   2815
# 8                                 Remote   1754

# %% [raw]
# ## Write your code here
# selected_columns = ["MainBranch","Employment","RemoteWork"]
# count_pattern = (df.groupby(selected_columns).size().reset_index(name="Count").sort_values("Count",ascending = False))
# count_pattern.head()

# %% [raw]
# duplicate_patterns = (
#     df.groupby(['MainBranch', 'Employment', 'RemoteWork'])
#       .size()
#       .reset_index(name='Count')
# )
#
# duplicates = duplicate_patterns[duplicate_patterns['Count'] > 1]
#
# duplicates.sort_values("Count", ascending=False).head(8)

# %%
#Analyse which other columns frequently share identical values within these response-pattern groups.
count_pattern = (df.groupby(["MainBranch","Employment","RemoteWork", "CodingActivities","EdLevel"]).size().reset_index(name="Count"))
count_pattern.sort_values("Count",ascending = False).head()
# Out:
#                          MainBranch           Employment  \
# 105  I am a developer by profession  Employed, full-time
# 819  I am a developer by profession  Employed, full-time
# 106  I am a developer by profession  Employed, full-time
# 294  I am a developer by profession  Employed, full-time
# 333  I am a developer by profession  Employed, full-time
#
#                                RemoteWork  \
# 105  Hybrid (some remote, some in-person)
# 819                                Remote
# 106  Hybrid (some remote, some in-person)
# 294  Hybrid (some remote, some in-person)
# 333  Hybrid (some remote, some in-person)
#
#                                       CodingActivities  \
# 105                                              Hobby
# 819                                              Hobby
# 106                                              Hobby
# 294  Hobby;Professional development or self-paced l...
# 333                       I don’t code outside of work
#
# ...

# %% [markdown]
# ### Task 3: Visualize Shared Response Patterns
# 1. Create visualizations to show the distribution of shared response patterns across different categories.
# 2. Use bar charts or pie charts to represent the distribution of respondents who share identical values for MainBranch, Employment, and RemoteWork, grouped by Country and Employment.

# %%
top_combination = df.groupby(["MainBranch","Employment","RemoteWork"]).size().idxmax()
filtered_df= df[
               (df["MainBranch"]==top_combination[0])&
               (df["Employment"]==top_combination[1])&
               (df["RemoteWork"]==top_combination[2])
]
filtered_df['Country'].value_counts().head(10).plot(kind='bar', color='blue', figsize=(10,5))
plt.title=(f"Top 10 Countries for Pattern:\n{top_combination}")
plt.xlabel=("Country")
plt.ylabel=("Respondent Count")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
filtered_df['Country'].value_counts().head(10).plot(kind='pie', autopct='%1.1f%%', figsize=(6,6))
plt.title ="Pattern respondents for Top 10 Countries"
plt.ylabel=("") # Hides the default column label for clean presentation
plt.show()

# %% [raw]
# ## Write your code here
# #count_pattern = (df.groupby(["MainBranch","Employment","RemoteWork", "CodingActivities","EdLevel"]).size().reset_index(name="Count").sort_values("Count",ascending = False))
# country_pattern = (df.groupby(["Country","MainBranch","Employment","RemoteWork"]).size().reset_index(name="Country_Count").sort_values("Country_Count",ascending = False))
# coutry_distribution = (country_pattern.groupby('Country')["Country_Count"].sum().sort_values(ascending= False))
# coutry_distribution.head()

# %% [raw]
# import matplotlib.pyplot as plt
#
# coutry_distribution.head(10).plot(kind = "bar", color ="Blue", figsize=(20,10))
# plt.title = "Pattern respondents for Top 10 Countries"
# plt.xlabel = "Countries"
# plt.ylabel = "Respondent Counts"
# plt.xticks(rotation =45)
# plt.tight_layout()
# plt.show()

# %% [markdown]
# ### Task 4: Evaluate Duplicate Handling Strategy
# 1. Analyse the dataset to determine which column(s) define record uniqueness.
# 2. Assess whether removing rows based on a subset of columns (rather than complete row duplication) is appropriate.
# Justify your decision with reference to the structure and purpose of the dataset.

# %% [raw]
# ## Write your analysis here
# Record uniqueness is defined by the respondent identifier (ResponseId), where each row represents a unique survey participant. Although multiple respondents may share the same values for columns such as MainBranch, Employment, and RemoteWork, these are valid response patterns rather than duplicate records. Therefore, removing rows based on a subset of columns is not appropriate, as it would eliminate legitimate responses and bias the analysis.

# %% [markdown]
# ## Verify and Document Duplicate Removal Process

# %% [markdown]
# ### Task 5: Documentation
# 1. Document the process of identifying and removing duplicates.

# %% [raw]
# # Write your explanation here
# The dataset was examined using Pandas' df.duplicated() method on all columns, ensuring that only records with identical values across every feature were identified as duplicates.

# %% [markdown]
# 2. Explain the reasoning behind selecting specific columns for identifying and removing duplicates.

# %% [raw]
# # Write your explanation here
# No specific subset of columns was selected for duplicate detection because the dataset represents individual survey responses, where respondents may legitimately share the same values in fields such as MainBranch, Employment, and RemoteWork. Using only a subset of columns could incorrectly classify valid responses as duplicates. Therefore, duplicates were identified using all columns, ensuring that only records with identical values across every feature were considered duplicates and removed.

# %% [markdown]
# ### Summary and Next Steps
# **In this lab, you focused on identifying and analyzing duplicate rows within the dataset.**
#
# - You employed various techniques to explore the nature of duplicates and applied strategic methods for their removal.
# - For additional analysis, consider investigating the impact of duplicates on specific analyses and how their removal affects the results.
# - This version of the lab is more focused on duplicate analysis and handling, providing a structured approach to deal with duplicates in a dataset effectively.

# %% [markdown]
# <!--
# ## Change Log
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2024-11- 05|1.3|Madhusudhan Moole|Updated lab|
# |2024-10-28|1.2|Madhusudhan Moole|Updated lab|
# |2024-09-24|1.1|Madhusudhan Moole|Updated lab|
# |2024-09-23|1.0|Raghul Ramesh|Created lab|
# --!>

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
